# %%
import pandas as pd

# Load the uploaded CSV file
file_path_test = "E:\CAP_FPT\2. CODE\2. Module 1 design\1. Hoang van Bac\ANLALYSIT_BB_UD_RESULT\MODEL_BB_ORIGIN\metrics\test\20250519_230726\all_metrics_summary.csv"
df_test = pd.read_csv(file_path_test)

file_path_train_valid = "E:\CAP_FPT\2. CODE\2. Module 1 design\1. Hoang van Bac\ANLALYSIT_BB_UD_RESULT\MODEL_BB_ORIGIN\metrics\training\20250515_092209\all_metrics_summary.csv"
df_train_valid = pd.read_csv(file_path_train_valid)
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[1], line 5
#       3 # Load the uploaded CSV file
#       4 file_path_test = "E:\CAP_FPT\2. CODE\2. Module 1 design\1. Hoang van Bac\ANLALYSIT_BB_UD_RESULT\MODEL_BB_ORIGIN\metrics\test\20250519_230726\all_metrics_summary.csv"
# ----> 5 df_test = pd.read_csv(file_path_test)
#       7 file_path_train_valid = "E:\CAP_FPT\2. CODE\2. Module 1 design\1. Hoang van Bac\ANLALYSIT_BB_UD_RESULT\MODEL_BB_ORIGIN\metrics\training\20250515_092209\all_metrics_summary.csv"
#       8 df_train_valid = pd.read_csv(file_path_train_valid)
#
# File ~\anaconda3\envs\dataScience\lib\site-packages\pandas\io\parsers\readers.py:912, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#     899 kwds_defaults = _refine_defaults_read(
#     900     dialect,
#     901     delimiter,
#    (...)
#     908     dtype_backend=dtype_backend,
#     909 )
#     910 kwds.update(kwds_defaults)
# --> 912 return _read(filepath_or_buffer, kwds)
#
# File ~\anaconda3\envs\dataScience\lib\site-packages\pandas\io\parsers\readers.py:577, in _read(filepath_or_buffer, kwds)
#     574 _validate_names(kwds.get("names", None))
#     576 # Create the parser.
# --> 577 parser = TextFileReader(filepath_or_buffer, **kwds)
#     579 if chunksize or iterator:
#     580     return parser
#
# File ~\anaconda3\envs\dataScience\lib\site-packages\pandas\io\parsers\readers.py:1407, in TextFileReader.__init__(self, f, engine, **kwds)
#    1404     self.options["has_index_names"] = kwds["has_index_names"]
#    1406 self.handles: IOHandles | None = None
# -> 1407 self._engine = self._make_engine(f, self.engine)
#
# File ~\anaconda3\envs\dataScience\lib\site-packages\pandas\io\parsers\readers.py:1661, in TextFileReader._make_engine(self, f, engine)
#    1659     if "b" not in mode:
#    1660         mode += "b"
# -> 1661 self.handles = get_handle(
#    1662     f,
#    1663     mode,
#    1664     encoding=self.options.get("encoding", None),
#    1665     compression=self.options.get("compression", None),
#    1666     memory_map=self.options.get("memory_map", False),
#    1667     is_text=is_text,
#    1668     errors=self.options.get("encoding_errors", "strict"),
#    1669     storage_options=self.options.get("storage_options", None),
#    1670 )
#    1671 assert self.handles is not None
#    1672 f = self.handles.handle
#
# File ~\anaconda3\envs\dataScience\lib\site-packages\pandas\io\common.py:859, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     854 elif isinstance(handle, str):
#     855     # Check whether the filename is to be opened in binary mode.
#     856     # Binary mode does not support 'encoding' and 'newline'.
#     857     if ioargs.encoding and "b" not in ioargs.mode:
#     858         # Encoding
# --> 859         handle = open(
#     860             handle,
#     861             ioargs.mode,
#     862             encoding=ioargs.encoding,
#     863             errors=errors,
#     864             newline="",
#     865         )
#     866     else:
#     867         # Binary mode
#     868         handle = open(handle, ioargs.mode)
#
# OSError: [Errno 22] Invalid argument: 'E:\\CAP_FPT\x02. CODE\x02. Module 1 design\x01. Hoang van Bac\\ANLALYSIT_BB_UD_RESULT\\MODEL_BB_ORIGIN\\metrics\test\x8250519_230726\x07ll_metrics_summary.csv'

# %%
# Kiểm tra xem tập train_valid có đủ các loại Dataset không
print("Các giá trị Dataset trong df_train_valid:", df_train_valid['Dataset'].unique())
# Out:
# Các giá trị Dataset trong df_train_valid: ['train' 'valid']

# %%
# Tính trung bình theo từng mô hình cho từng loại Dataset
mean_train = df_train_valid[df_train_valid['Dataset'] == 'train'].groupby('Model').mean(numeric_only=True).reset_index()
mean_valid = df_train_valid[df_train_valid['Dataset'] == 'valid'].groupby('Model').mean(numeric_only=True).reset_index()
mean_test = df_test.groupby('Model').mean(numeric_only=True).reset_index()

# %%
# Hiển thị kết quả
print("Trung bình TRAIN:")
print(mean_train)

print("\nTrung bình VALID:")
print(mean_valid)

print("\nTrung bình TEST:")
print(mean_test)
# Out:
# Trung bình TRAIN:
#                  Model  Accuracy  Precision    Recall        F1
# 0  logistic_regression  0.889758   0.887564  0.889758  0.883966
# 1                 lstm  0.817888   0.804701  0.817888  0.789615
# 2                  svm  0.896488   0.900224  0.896488  0.892372
# 3          transformer  0.787603   0.803699  0.787603  0.768597
#
# Trung bình VALID:
#                  Model  Accuracy  Precision    Recall        F1
# 0  logistic_regression  0.638059   0.656900  0.638059  0.607928
# 1                 lstm  0.700050   0.701362  0.700050  0.668190
# 2                  svm  0.632148   0.652474  0.632148  0.596020
# 3          transformer  0.689237   0.708925  0.689237  0.662871
#
# Trung bình TEST:
#                  Model  Accuracy  Precision    Recall        F1
# 0  logistic_regression  0.585466   0.592871  0.585466  0.549096
# 1                 lstm  0.599760   0.605624  0.599760  0.564579
# 2                  svm  0.542781   0.535228  0.542781  0.500861
# 3          transformer  0.600654   0.625636  0.600654  0.567880
